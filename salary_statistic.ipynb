# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
salary = pd.read_csv("salary.csv")
#salary.info()
salary.head()
# Out:
#    Unnamed: 0   Age  Gender Education Level          Job Title  \
# 0           0  32.0    Male      Bachelor's  Software Engineer
# 1           1  28.0  Female        Master's       Data Analyst
# 2           2  45.0    Male             PhD     Senior Manager
# 3           3  36.0  Female      Bachelor's    Sales Associate
# 4           4  52.0    Male        Master's           Director
#
#    Years of Experience    Salary Country      Race
# 0                  5.0   90000.0      UK     White
# 1                  3.0   65000.0     USA  Hispanic
# 2                 15.0  150000.0  Canada     White
# 3                  7.0   60000.0     USA  Hispanic
# 4                 20.0  200000.0     USA     Asian

# %%
salary.describe()
# Out:
#         Unnamed: 0          Age  Years of Experience         Salary
# count  6704.000000  6702.000000          6701.000000    6699.000000
# mean   3351.500000    33.620859             8.094687  115326.964771
# std    1935.422435     7.614633             6.059003   52786.183911
# min       0.000000    21.000000             0.000000     350.000000
# 25%    1675.750000    28.000000             3.000000   70000.000000
# 50%    3351.500000    32.000000             7.000000  115000.000000
# 75%    5027.250000    38.000000            12.000000  160000.000000
# max    6703.000000    62.000000            34.000000  250000.000000

# %%
#Top 10
salary.nlargest(10, 'Salary')
# Out:
#       Unnamed: 0   Age Gender    Education Level                 Job Title  \
# 30            30  50.0   Male         Bachelor's                       CEO
# 83            83  52.0   Male                PhD  Chief Technology Officer
# 5001        5001  45.0   Male  Bachelor's Degree         Financial Manager
# 4276        4276  51.0   Male                PhD            Data Scientist
# 4291        4291  51.0   Male                PhD            Data Scientist
# 4306        4306  51.0   Male                PhD            Data Scientist
# 4321        4321  51.0   Male                PhD            Data Scientist
# 4336        4336  51.0   Male                PhD            Data Scientist
# 4351        4351  51.0   Male                PhD            Data Scientist
# 4366        4366  51.0   Male                PhD            Data Scientist
#
#       Years of Experience    Salary Country     Race
# 30                   25.0  250000.0  Canada    Asian
# ...

# %%
mean = salary.groupby('Race')['Salary'].mean().reset_index()
mean.sort_values(by=['Salary'], inplace=True)
print(mean)

plt.bar(range(len(mean)), mean['Salary'], color="green",  align='center')

plt.xticks(range(len(mean)), mean['Race'], rotation='vertical')
plt.ylabel('Mean Salary')
# Out:
#                Race         Salary
# 5          Hispanic  110410.139752
# 4           Chinese  111139.315315
# 0  African American  112209.658192
# 8             Welsh  112560.645646
# 2        Australian  114236.676991
# 1             Asian  115302.068621
# 7             Mixed  116330.859281
# 9             White  117071.055527
# 6            Korean  117099.757112
# 3             Black  118601.212815
# Text(0, 0.5, 'Mean Salary')

# %%
mean = salary.groupby('Gender')['Salary'].mean().reset_index()
mean.sort_values(by=['Salary'], inplace=True)
print(mean)

plt.bar(range(len(mean)), mean['Salary'], color="pink",  align='center')

plt.xticks(range(len(mean)), mean['Gender'], rotation='vertical')
plt.ylabel('Mean Salary')
# Out:
#    Gender         Salary
# 0  Female  107888.998672
# 1    Male  121389.870915
# 2   Other  125869.857143
# Text(0, 0.5, 'Mean Salary')

# %%
mean = salary.groupby('Job Title')['Salary'].mean().reset_index()

# %%
mean.nlargest(10, 'Salary')
# Out:
#                        Job Title         Salary
# 7                            CEO  250000.000000
# 9       Chief Technology Officer  250000.000000
# 8             Chief Data Officer  220000.000000
# 28      Director of Data Science  204561.403509
# 26                      Director  200000.000000
# 190                VP of Finance  200000.000000
# 102          Operations Director  190000.000000
# 191             VP of Operations  190000.000000
# 33   Director of Human Resources  187500.000000
# 96            Marketing Director  183984.375000

# %%
mean.nsmallest(10, 'Salary')
# Out:
#                               Job Title        Salary
# 61   Junior Business Operations Analyst  17675.000000
# 112                        Receptionist  25000.000000
# 21                      Delivery Driver  28000.000000
# 83               Junior Sales Associate  28211.267606
# 92               Juniour HR Coordinator  32000.000000
# 15      Customer Service Representative  33333.333333
# 19                     Data Entry Clerk  35000.000000
# 49                    Help Desk Analyst  35000.000000
# 63   Junior Customer Support Specialist  35000.000000
# 87            Junior Software Developer  35810.344828

# %%
n, bins, patches = plt.hist(salary['Age'], bins='auto', color='#0504aa',
                            alpha=0.7, rwidth=0.85)

plt.grid(axis='y', alpha=0.75)
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Histogram of age')
# Out:
# Text(0.5, 1.0, 'Histogram of age')
